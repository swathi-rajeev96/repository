# %% [markdown]
# # student data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
student=pd.read_csv('student.csv')

# %%
student.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
x=student[['Math','Reading']]
y=student[['Writing']]

# %%
#splitting in to train and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0) #random states keeps a fixes set of oututs to work with
len(x_train),len(x_test),len(y_train),len(y_test)
# Out:
# (800, 200, 800, 200)

# %%
#create the model
lm2=LinearRegression()
#fit the model
model2=lm2.fit(x_train,y_train)
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# [-1.9502733]
# [[0.09356445 0.91854045]]

# %%
#predict the results for x_test
y_pred=model2.predict(x_test)

# %%
#model evaluation
rmse2=np.sqrt(mean_squared_error(y_test,y_pred))
r=r2_score(y_test,y_pred)
print('rmse is ',rmse2)
print('r square is ',r)
# Out:
# rmse is  4.414674861496005
# r square is  0.9052409628220129

# %%
#3D scatter plot
from mpl_toolkits.mplot3d import Axes3D
math=student['Math'].values
read=student['Reading'].values
write=student['Writing'].values

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.scatter(math,read,write,color='brown')
plt.show()

# %%
#residual plot
x_plot=plt.scatter(y_pred,(y_pred-y_test),c='r')
plt.hlines(y=0,xmin=-10,xmax=100)
plt.title('residual plot')
# Out:
# Text(0.5, 1.0, 'residual plot')

# %% [markdown]
# ##### If the points in a residual plot are randomly dispersed around the horizontal axis, a linear regression model is appropriate for the data; otherwise, a non-linear model is more appropriate.

# %% [markdown]
# # Head-Brain

# %%
data=pd.read_csv('headbrain.csv')
data.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X=data.loc[:,['Gender','Age Range','Head Size(cm^3)']]
Y=data.loc[:,['Brain Weight(grams)']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0) #random states keeps a fixes set of oututs to work with
len(X_train),len(X_test),len(Y_train),len(Y_test)
# Out:
# (189, 48, 189, 48)

# %%
#create the model
lm3=LinearRegression()
#fit the model
model3=lm3.fit(X_train,Y_train)
print(lm3.intercept_)
print(lm3.coef_)
#predict the results for x_test
Y_pred=model3.predict(X_test)
# Out:
# [465.9877711]
# [[-15.10813997 -27.67412051   0.24252694]]

# %%
rmse2=np.sqrt(mean_squared_error(Y_test,Y_pred))
r=r2_score(Y_test,Y_pred)
print('rmse is ',rmse2)
print('r square is ',r)
# Out:
# rmse is  71.23878018173185
# r square is  0.6463914618720078

# %%
#residual plot
x_plot=plt.scatter(Y_pred,(Y_pred-Y_test),c='r')
plt.hlines(y=0,xmin=-10,xmax=100)
plt.title('residual plot')
# Out:
# Text(0.5, 1.0, 'residual plot')

# %% [markdown]
# # Train data

# %%
train=pd.read_csv('Train.csv')
train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
train1 = train.dropna(axis = 0, how = 'any')
train1.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
train1['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'reg', 'LF'], dtype=object)

# %%
def to_numerical(fat_cont):
    if ((fat_cont == 'Low Fat') | (fat_cont == 'low fat') | (fat_cont == 'LF')):
        return 1
    elif ((fat_cont == 'Regular') | (fat_cont == 'reg')):
        return 2
    else:
        return 0

    
train1['Item_Fat_Content'] = train1['Item_Fat_Content'].apply(to_numerical)
train1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 4              NCD19        8.930                 1         0.000000
# 5              FDP36       10.395                 2         0.000000
# 6              FDO10       13.650                 2         0.012741
# 10             FDY07       11.800                 1         0.000000
# ...

# %%
train1['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
def to_numerical(os):
    if (os == 'Small'):
        return 1
    elif (os == 'Medium'):
        return 2
    elif (os == 'High'):
        return 3
    else:
        return 0

    
train1['Outlet_Size'] = train1['Outlet_Size'].apply(to_numerical)
train1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 4              NCD19        8.930                 1         0.000000
# 5              FDP36       10.395                 2         0.000000
# 6              FDO10       13.650                 2         0.012741
# 10             FDY07       11.800                 1         0.000000
# ...

# %%
train1['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2'], dtype=object)

# %%
def to_numerical(sm):
    if (sm == 'Supermarket Type1'):
        return 1
    elif (sm == 'Supermarket Type2'):
        return 2
    else:
        return 0

    
train1['Outlet_Type'] = train1['Outlet_Type'].apply(to_numerical)
train1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 4              NCD19        8.930                 1         0.000000
# 5              FDP36       10.395                 2         0.000000
# 6              FDO10       13.650                 2         0.012741
# 10             FDY07       11.800                 1         0.000000
# ...

# %%
train1['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
def to_numerical(olt):
    if (olt == 'Tier 1'):
        return 1
    elif (olt == 'Tier 2'):
        return 2
    elif (olt == 'Tier 3'):
        return 3
    else:
        return 0

    
train1['Outlet_Location_Type'] = train1['Outlet_Location_Type'].apply(to_numerical)
train1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#      Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300                 1         0.016047
# 1              DRC01        5.920                 2         0.019278
# 2              FDN15       17.500                 1         0.016760
# 4              NCD19        8.930                 1         0.000000
# 5              FDP36       10.395                 2         0.000000
# 6              FDO10       13.650                 2         0.012741
# 10             FDY07       11.800                 1         0.000000
# ...

# %%
# Merging the independent variables to one

x = train1.loc[:,['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_MRP', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']]
y = train1.loc[:,'Item_Outlet_Sales']
#print(x, y)

lm = LinearRegression()

model = lm.fit(x, y)

print('Intercept Value: ', lm.intercept_)
print('Cofficient: ', lm.coef_)
# Out:
# Intercept Value:  445.8084490291765
# Cofficient:  [  -3.76572232   13.19277202 -160.87030197   16.31253598  -26.78375097
#    17.50787341 -359.99747172]

# %%
# Step 1: Splitting the data into training and test

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state =0)  # train_size = 0.8
len(x_train), len(x_test), len(y_train), len(y_test)

# Creating the model

lm1 = LinearRegression()


# Fitting the model

model1 = lm1.fit(x_train, y_train)
print('a0=', lm1.intercept_)
print('a1=', lm1.coef_)

y_pred = lm1.predict(x_test)
print('Predicted values are:\n', y_pred)
# Out:
# a0= 572.3002016394857
# a1= [  -6.64652963   -8.47084405 -443.11759061   16.17961607  -28.08154916
#     5.08013169 -358.50897661]
# Predicted values are:
#  [4173.41615392  894.32592966 2565.36880967 2421.26708216 2636.35763769
#  3264.69849259 1972.82781217 1259.46251986 2172.94096299 3448.10174014
#  1518.17470208 1842.08295182 3873.70197432  604.11484496  714.02714205
#  1710.41940348 2198.01456037  904.88871182 2673.17803409 2909.6936166
#  2406.43603793 3261.72345003 2017.10152818 2224.83695763 2901.44373257
#  4083.90721827 3142.51394149 4159.80701284 2667.27716094 1383.30443763
#  1103.29936469 3251.8381981   864.232481   3010.24023515 2852.17488837
#  2422.80564028 4218.29186394 3090.68495922 1111.77708139 3633.34468384
#  1074.09829096 4135.25589339 2814.8355476  3913.8449171  2430.02665951
#  3185.15610347 1580.11630849 1629.34833787 1291.15629312 2879.01934922
#   536.72208672  311.04317725 1618.65817144 1669.72760443 3631.1476663
# ...

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE= ', rmse)

r2 = r2_score(y_test, y_pred)
print('Regressor Score is: ', r2)
# Out:
# RMSE=  1108.4470574986767
# Regressor Score is:  0.4707521759610005

# %%
#regularisation
predictors = x_train.columns
coef = pd.Series(lm1.coef_, predictors).sort_values()
coef.plot(kind = 'bar', title = 'Modal coefficients')

# %% [markdown]
# # Ridge Regression

# %% [markdown]
# ### we would like to decrease the model complexity, that is the number of predictors. We could use the forward or backward selection for this, but that way we would not be able to tell anything about the removed variables' effect on the response. Removing predictors from the model can be seen as settings their coefficients to zero. Instead of forcing them to be exactly zero, let's penalize them if they are too far from zero, thus enforcing them to be small in a continuous way. This way, we decrease model complexity while keeping all variables in the model. This, basically, is what Ridge Regression does.

# %%
from sklearn.linear_model import Ridge

# %%
ridgeReg=Ridge(alpha=5,normalize=True)
ridgeReg.fit(x_train,y_train)
pred=ridgeReg.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,pred))
r2=r2_score(y_test,pred)
print(rmse)
print(r2)
predictors=x_train.columns
coef=pd.Series(ridgeReg.coef_,predictors).sort_values()
coef.plot(kind='bar',title='Modal Coefficients')
# Out:
# 1413.8676003280232
# 0.13891374606181273

# %% [markdown]
# ### higher the alpha value lesser the r square

# %% [markdown]
# # Lasso Regression

# %% [markdown]
# ### Lasso, or Least Absolute Shrinkage and Selection Operator, is quite similar conceptually to ridge regression. It also adds a penalty for non-zero coefficients, but unlike ridge regression which penalizes sum of squared coefficients, lasso penalizes the sum of their absolute values. As a result, for high values of alpha many coefficients are exactly zeroed under lasso, which is never the case in ridge regression.

# %%
from sklearn.linear_model import Lasso
#alpha=0.01,0.05,0.5,5
lassoReg=Lasso(alpha=0.7,normalize=True)
lassoReg.fit(x_train,y_train)
pred=lassoReg.predict(x_test)
rmse=np.sqrt(mean_squared_error(y_test,pred))
r2=r2_score(y_test,pred)
print(rmse)
print(r2)
predictors=x_train.columns
coef=pd.Series(lassoReg.coef_,predictors).sort_values()
coef.plot(kind='bar',title='Modal Coefficients')
# Out:
# 1107.8803610061052
# 0.47129319632885824

# %% [markdown]
# ###### first we have to check r .sq  for different values of alpha,which gives max r square that is the good model.Here in lasso wen we put alpha=0.5,we infer that outlet type(negatively correlated) and item mrp(positive corr) affects the sales
